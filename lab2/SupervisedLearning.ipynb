# %% [markdown]
# This code is an introduction to supervised learning solving a classification problem using **decision trees**.
# It follows [this tutorial](https://youtu.be/7eh4d6sabA0).

# %% [markdown]
# # **Classification Problem**
# We will follow these steps of solving a machine learning problem.
#
#
# 1. Import the Data
# 2. Clean the Data
# 3. split the Data into Training/ Test steps
# 4. Create a Model
# 5. Train the Model
# 6. Make Predictions
# 7. Evaluate and improve

# %% [markdown]
# # Problem description
# Enter in the text cell below what you will be predicting in this classification problem (y) and which columns will be used in the prediction (X)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import joblib
from sklearn import tree

# %% [markdown]
# 1. Import the Data.

# %%
df = pd.read_csv('cleanedfile.csv')

# %% [markdown]
# 2. Display columns and describe the data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      56 non-null     int64
#  1   season          56 non-null     int64
#  2   week_num        56 non-null     int64
#  3   day_of_week     56 non-null     object
#  4   gametime_local  56 non-null     object
#  5   home_team       56 non-null     object
#  6   away_team       56 non-null     object
#  7   home_score      56 non-null     int64
#  8   away_score      56 non-null     int64
#  9   OT_flag         56 non-null     object
#  10  arrests         56 non-null     float64
#  11  division_game   56 non-null     object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 5.4+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0       season   week_num  home_score  away_score    arrests
# count   56.000000    56.000000  56.000000   56.000000   56.000000  56.000000
# mean   464.714286  2012.821429   9.803571   24.035714   22.964286   7.017857
# std    332.005516     1.363247   4.441210    7.258761    7.236183  10.370397
# min      3.000000  2011.000000   1.000000   13.000000   10.000000   0.000000
# 25%    187.750000  2012.000000   6.750000   19.750000   17.000000   1.000000
# 50%    439.000000  2013.000000  10.000000   23.000000   23.000000   3.000000
# 75%    781.750000  2014.000000  13.000000   29.000000   26.250000   7.250000
# max    985.000000  2015.000000  17.000000   44.000000   41.000000  41.000000

# %% [markdown]
# 3. Prepare Data

# %%
# Run this section to inspect X
X = df.drop(columns = ['home_score'])
X
# Out:
#     Unnamed: 0  season  week_num day_of_week gametime_local        home_team  \
# 0            3    2011         9      Sunday     2:15:00 PM          Arizona
# 1            4    2011        13      Sunday     2:15:00 PM          Arizona
# 2            6    2011        15      Sunday     2:15:00 PM          Arizona
# 3            7    2011        17      Sunday     2:15:00 PM          Arizona
# 4           10    2012         4      Sunday     1:05:00 PM          Arizona
# 5           11    2012         6      Sunday     1:05:00 PM          Arizona
# 6           50    2013        10      Sunday     1:00:00 PM        Baltimore
# 7           64    2015         5      Sunday     1:02:00 PM        Baltimore
# 8           84    2012        11      Sunday     1:00:00 PM         Carolina
# 9          106    2015         8      Monday     8:30:00 PM         Carolina
# 10         125    2012        13      Sunday    12:00:00 PM          Chicago
# 11         132    2013        11      Sunday    12:00:00 PM          Chicago
# 12         135    2014         1      Sunday    12:00:00 PM          Chicago
# 13         169    2014         6      Sunday     1:00:00 PM       Cincinnati
# 14         194    2012        11      Sunday    12:00:00 PM           Dallas
# 15         197    2012        15      Sunday     3:25:00 PM           Dallas
# 16         198    2012        16      Sunday    12:00:00 PM           Dallas
# 17         209    2014         5      Sunday    12:00:00 PM           Dallas
# 18         211    2014         8      Monday     7:30:00 PM           Dallas
# 19         219    2015         9      Sunday     7:30:00 PM           Dallas
# 20         228    2011        14      Sunday     2:05:00 PM           Denver
# 21         259    2015        12      Sunday     6:30:00 PM           Denver
# 22         261    2015        16      Monday     6:30:00 PM           Denver
# 23         324    2013        12      Sunday    12:00:00 PM        Green Bay
# 24         356    2012        11      Sunday    12:00:00 PM          Houston
# 25         359    2013         2      Sunday    12:00:00 PM          Houston
# 26         360    2013         4      Sunday    12:00:00 PM          Houston
# 27         416    2015         4      Sunday     1:00:00 PM     Indianapolis
# 28         462    2011         8      Monday     7:30:00 PM      Kansas City
# 29         467    2011        16    Saturday    12:00:00 PM      Kansas City
# 30         510    2013         9    Thursday     8:25:00 PM            Miami
# 31         540    2012         7      Sunday     4:25:00 PM      New England
# 32         551    2013        12      Sunday     8:30:00 PM      New England
# 33         607    2015        13      Sunday     1:00:00 PM  New York Giants
# 34         629    2013         7      Sunday     1:00:00 PM    New York Jets
# 35         649    2015        16      Sunday     1:00:00 PM    New York Jets
# 36         660    2012         7      Sunday     1:25:00 PM          Oakland
# 37         697    2012         6      Sunday     1:00:00 PM     Philadelphia
# 38         738    2012        10      Monday     8:30:00 PM       Pittsburgh
# 39         760    2015         4    Thursday     8:30:00 PM       Pittsburgh
# 40         772    2011        12      Sunday     1:15:00 PM        San Diego
# 41         779    2012        12      Sunday     1:05:00 PM        San Diego
# 42         790    2013        17      Sunday     1:25:00 PM        San Diego
# 43         808    2011         2      Sunday     1:05:00 PM    San Francisco
# 44         819    2012        10      Sunday     1:25:00 PM    San Francisco
# 45         837    2014        16    Saturday     5:25:00 PM    San Francisco
# 46         846    2015        17      Sunday     1:25:00 PM    San Francisco
# 47         866    2013         9      Sunday     1:05:00 PM          Seattle
# 48         872    2014         3      Sunday     1:25:00 PM          Seattle
# 49         913    2014         8      Sunday     1:00:00 PM        Tampa Bay
# 50         935    2012         3      Sunday    12:00:00 PM        Tennessee
# 51         937    2012         8      Sunday    12:00:00 PM        Tennessee
# 52         948    2013        15      Sunday     3:25:00 PM        Tennessee
# 53         970    2011        11      Sunday     1:00:00 PM       Washington
# 54         980    2012        14      Sunday     1:00:00 PM       Washington
# 55         985    2013         9      Sunday     1:00:00 PM       Washington
#
#         away_team  away_score OT_flag  arrests division_game
# 0       St. Louis          13      OT      6.0             y
# 1          Dallas          13      OT      3.0             n
# 2       Cleveland          17      OT      1.0             n
# 3         Seattle          20      OT      4.0             y
# 4           Miami          21      OT      4.0             n
# 5         Buffalo          16      OT      1.0             n
# 6      Cincinnati          17      OT      0.0             y
# 7       Cleveland          33      OT      3.0             y
# 8       Tampa Bay          27      OT      0.0             y
# 9    Indianapolis          26      OT      6.0             n
# 10        Seattle          23      OT      0.0             n
# 11      Baltimore          10      OT      2.0             n
# 12        Buffalo          23      OT      1.0             n
# 13       Carolina          37      OT      1.0             n
# 14      Cleveland          20      OT      0.0             n
# 15     Pittsburgh          24      OT     13.0             n
# 16    New Orleans          34      OT      0.0             n
# 17        Houston          17      OT      7.0             n
# 18     Washington          20      OT      3.0             y
# 19   Philadelphia          33      OT      8.0             y
# 20        Chicago          10      OT      0.0             n
# 21    New England          24      OT      3.0             n
# 22     Cincinnati          17      OT      1.0             n
# 23      Minnesota          26      OT      8.0             y
# 24   Jacksonville          37      OT      1.0             y
# 25      Tennessee          24      OT      2.0             y
# 26        Seattle          23      OT      0.0             n
# 27   Jacksonville          13      OT      0.0             y
# 28      San Diego          20      OT      2.0             y
# 29        Oakland          16      OT      2.0             y
# 30     Cincinnati          20      OT      0.0             n
# 31  New York Jets          26      OT      4.0             y
# 32         Denver          31      OT      4.0             n
# 33  New York Jets          23      OT     39.0             n
# 34    New England          27      OT     29.0             y
# 35    New England          20      OT     32.0             y
# 36   Jacksonville          23      OT     16.0             n
# 37        Detroit          26      OT      1.0             n
# 38    Kansas City          13      OT     25.0             n
# 39      Baltimore          23      OT      1.0             y
# 40         Denver          16      OT     41.0             y
# 41      Baltimore          16      OT     31.0             n
# 42    Kansas City          24      OT      8.0             y
# 43         Dallas          27      OT      4.0             n
# 44      St. Louis          24      OT      8.0             y
# 45      San Diego          38      OT     25.0             n
# 46      St. Louis          16      OT     18.0             y
# 47      Tampa Bay          24      OT      2.0             n
# 48         Denver          20      OT      1.0             n
# 49      Minnesota          19      OT      0.0             n
# 50        Detroit          41      OT      1.0             n
# 51   Indianapolis          19      OT      0.0             y
# 52        Arizona          37      OT      7.0             n
# 53         Dallas          27      OT      7.0             y
# 54      Baltimore          28      OT      4.0             n
# 55      San Diego          24      OT      3.0             n

# %%
# Uncomment this section to inpect y
y = df['away_score']
y
# Out:
# 0     13
# 1     13
# 2     17
# 3     20
# 4     21
# 5     16
# 6     17
# 7     33
# 8     27
# 9     26
# 10    23
# 11    10
# 12    23
# 13    37
# 14    20
# 15    24
# 16    34
# 17    17
# 18    20
# 19    33
# 20    10
# 21    24
# 22    17
# 23    26
# 24    37
# 25    24
# 26    23
# 27    13
# 28    20
# 29    16
# 30    20
# 31    26
# 32    31
# 33    23
# 34    27
# 35    20
# 36    23
# 37    26
# 38    13
# 39    23
# 40    16
# 41    16
# 42    24
# 43    27
# 44    24
# 45    38
# 46    16
# 47    24
# 48    20
# 49    19
# 50    41
# 51    19
# 52    37
# 53    27
# 54    28
# 55    24
# Name: away_score, dtype: int64

# %% [markdown]
# 4. Calculate accuracy

# %%
# Train 80% of the data set and use the rest to test
X_train, X_test, y_train, y_test = train_test_split(
                                    X, y, test_size=0.2)

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

# Compute model accuracy
score = accuracy_score(y_test, predictions)
score
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_66/1876563117.py in <module>
#       4
#       5 model = DecisionTreeClassifier()
# ----> 6 model.fit(X_train, y_train)
#       7 predictions = model.predict(X_test)
#       8
#
# /usr/lib/python3.9/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# /usr/lib/python3.9/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     163             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     164             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 165             X, y = self._validate_data(
#     166                 X, y, validate_separately=(check_X_params, check_y_params)
#     167             )
#
# /usr/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     567                 # :(
#     568                 check_X_params, check_y_params = validate_separately
# --> 569                 X = check_array(X, **check_X_params)
#     570                 y = check_array(y, **check_y_params)
#     571             else:
#
# /usr/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     736                     array = array.astype(dtype, casting="unsafe", copy=False)
#     737                 else:
# --> 738                     array = np.asarray(array, order=order, dtype=dtype)
#     739             except ComplexWarning as complex_warning:
#     740                 raise ValueError(
#
# /usr/lib/python3.9/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1991
#    1992     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993         return np.asarray(self._values, dtype=dtype)
#    1994
#    1995     def __array_wrap__(
#
# ValueError: could not convert string to float: 'Saturday'

# %% [markdown]
# 5. Persisting Models

# %%
# Save the model to file
joblib.dump(model, 'MODELNAME.joblib')

# %% [markdown]
# 5.b. Import the model and make predictions

# %%
# Load saved model. Make sure that you have run the previous
# section at least once, and that the file exists.

model = joblib.load('MODELNAME.joblib')
predictions = model.predict(X_test)
predictions

# %% [markdown]
# 6. (Optional) Visualize decision trees

# %%
tree.export_graphviz(model, out_file = 'MODELNAME.dot',
                    feature_names = X.columns, 
                    class_names = str(sorted(y.unique())), 
                    label = 'all',
                    rounded = True, 
                    filled = True)

#Download the file music-recommender.dot and open it in VS Code.
